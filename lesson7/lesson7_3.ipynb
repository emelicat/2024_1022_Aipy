# %%
#list
list1 = [1, 44 ,77, 103]
list1
# Out:
# [1, 44, 77, 103]

# %%
list1[0],list1[1],list1[2],list1[3]
# Out:
# (1, 44, 77, 103)

# %%
for index,value in enumerate(list1):
    print(index)
    print(value)
    print("============")
# Out:
# 0
# 1
# ...
# 1
# 44
# ...
# 2
# 77
# ...
# 3
# 103
# ...

# %%
list2:list = [1, 44 ,77, 103]
list2
type(list2)
# Out:
# list

# %%
list2.insert(0,100)
list2
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100, 1, 44, 77, 103]

# %%
#append
list2.append(67)
list2
# Out:
# [100, 100, 100, 100, 100, 100, 100, 100, 1, 44, 77, 103, 67, 67, 67, 67, 67]

# %%
list2.clear()

# %%
list2
# Out:
# []

# %% [markdown]
# ![image.png](attachment:image.png)
