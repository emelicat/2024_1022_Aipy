# %%
class Person(object):
    def __init__(self):
        self.name = "Alex"
        self.age = 21

# %%
p1:Person = Person()
p1.name, p1.age
# Out:
# ('Alex', 21)

# %%
p2:Person = Person()
p2.age, p2.name
# Out:
# (21, 'Alex')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person(object):
    def __init__(self,name:str,age:int):
        self.name = name
        self.age = age

# %%
p1 = Person(name="Alex", age=21)
p1.name , p1.age
# Out:
#   Cell In[27], line 2
#     p1.name , p1.age p1.echo
#                      ^
# SyntaxError: invalid syntax

# %%
p2 = Person(name="anna", age=21)
p2.name , p2.age
# Out:
# ('anna', 21)

# %%
class Person(object):
    def __init__(self,name:str,age:int):
        self.name = name
        self.age = age
    
    def echo(self): #自訂的實體方法
        print(f"我的名字是{self.name}")
        print(f"我今年{self.age}歲")

# %%
p1 = Person(name="Alex", age=21)
p1.echo()
# Out:
# 我的名字是Alex
# 我今年21歲

# %%
p2 = Person(name="Anna", age=21)
p2.echo()
# Out:
# 我的名字是Anna
# 我今年21歲
